# %% [markdown]
# # Python Basics Practice Notebook
#
# This notebook will help you practice fundamental Python concepts:
#
# - Variables
# - Data types
# - Lists & dictionaries
# - Loops
# - Functions
# - Conditionals
# - Strings
# - NumPy arrays
#
# > **Note:** Feel free to use the internet, Python documentation, or any other resources to help you solve the exercises.

# %% [markdown]
# ## 1. Variables
# Assign values to variables below.

# %%
# TODO: Create variables 'a' and 'b' and assign numbers to them
a = 
b = 
# Add them together and print the result
c = 
print(c)

# %% [markdown]
# ## 2. Lists
# Create a list of 5 numbers.

# %%
# TODO: Create a list of numbers named 'my_list'
my_list = []


# Print the first and last element
print(my_list[])
print(my_list[])

# Try to add a new number to the list and remove one number.

# %% [markdown]
# ## 3. Loops
# Write a loop that prints each item in a list.

# %%
# TODO: Loop through my_list and print items
for item in my_list:

# %% [markdown]
# ## 4. Functions
# Write a function that takes a number and returns its square.

# %%
# TODO: Write your function
def square(x):
    pass

# Test
square(3)

# Write a function that takes a list of numbers and returns a new list with all numbers squared

# %% [markdown]
# ## 5. Conditionals
#
# Practice using if, elif, and else.

# %%
# TODO: Check if a number is positive, negative, or zero
num = 
if :
    print("Positive")
elif :
    print("Negative")
else:
    print("Zero")

# %% [markdown]
# ## 6. Strings

# %%
# TODO: Create a string variable called 'my_string'
my_string = ""

# Print its length and the first character

# Convert the string to uppercase and replace spaces with underscores

# %% [markdown]
# ## 7. NumPy Exercises
#
# NumPy is a powerful library for numerical computing in Python.
#
# To use the library, we need to import it.

# %%
import numpy as np

# %%
# TODO: Create a numpy array with numbers
arr = 

# Print the array

# Multiply by 2
arr2 = 

# Print results
print(arr2)

# Find the sum, mean, and maximum of the array using NumPy functions
