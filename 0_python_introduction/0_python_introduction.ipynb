# %% [markdown]
# # Python Basics Practice Notebook
# Welcome! This notebook will help you practice fundamental Python concepts:
# - Variables
# - Data types
# - Lists & dictionaries
# - Loops
# - Functions

# %% [markdown]
# ## 1. Variables
# Assign values to variables below.

# %%
# TODO: Create variables 'a' and 'b' and assign numbers to them
a = 
b = 
a + b

# %% [markdown]
# ## 2. Lists
# Create a list of 5 numbers.

# %%
# TODO: Create a list named 'my_list'
my_list = []
my_list

# %% [markdown]
# ## 3. Loops
# Write a loop that prints each item in a list.

# %%
# TODO: Loop through my_list and print items
for item in my_list:
    print(item)

# %% [markdown]
# ## 4. Functions
# Write a function that takes a number and returns its square.

# %%
# TODO: Write your function
def square(x):
    pass

# Test
square(3)
